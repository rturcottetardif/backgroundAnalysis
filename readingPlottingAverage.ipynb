# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
run /home/rturcotte/work/scripts/backgroundAnalysis/averages.py /data/user/rturcotte/work/i3files/eventData_1580896873_2020-02-05_10-01-13_00.i3.gz
# Out:
# begin ...
# finish

# %%
# %cd /data/user/rturcotte/work/i3files/means/
npzfile = np.load("average_1580896873.npz")
print(npzfile.files)
spectrum = npzfile["spectrum"]
timeSerie = npzfile["timeSerie"]
freq = npzfile["freq"]

# %%
plt.plot(freq, spectrum)
plt.xlabel("frequency / MHz")
plt.ylabel("who knows")
# Out:
# /cvmfs/icecube.opensciencegrid.org/py3-v4.1.0/RHEL_7_x86_64/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# Text(0,0.5,'who knows')

# %%
plt.plot(timeSerie)
plt.xlabel("time / ns")
plt.ylabel("amplitude / ADC count")
# Out:
# Text(0,0.5,'amplitude / ADC count')
